# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Advent-of-Code-2021" data-toc-modified-id="Advent-of-Code-2021-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Advent of Code 2021</a></span><ul class="toc-item"><li><span><a href="#Reader-Function" data-toc-modified-id="Reader-Function-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Reader Function</a></span></li><li><span><a href="#Day-1" data-toc-modified-id="Day-1-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Day 1</a></span><ul class="toc-item"><li><span><a href="#Part-1" data-toc-modified-id="Part-1-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Part 1</a></span><ul class="toc-item"><li><span><a href="#Test" data-toc-modified-id="Test-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Test</a></span></li><li><span><a href="#Real-Data" data-toc-modified-id="Real-Data-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Real Data</a></span></li></ul></li><li><span><a href="#Part-2" data-toc-modified-id="Part-2-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Part 2</a></span></li></ul></li><li><span><a href="#Reader-function" data-toc-modified-id="Reader-function-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Reader function</a></span></li></ul></li><li><span><a href="#Terminal-Section" data-toc-modified-id="Terminal-Section-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Terminal Section</a></span></li></ul></div>

# %% [markdown]
# # Advent of Code 2021

# %% [markdown]
# ## Reader Function

# %%
def get_data(day=1):
    """
    Returns test and real data in list format.
    Raw data should be maintained as:
        [test data]
        Split From Here
        [actual data]
    """
    file_name = f"data/day{day}.txt"
    
    with open(file_name) as fp:
        data = fp.read().strip().split("Split From Here")
        data = [d.strip().split("\n") for d in data]
        return data
get_data()
# Out:
# [['199', '200', '208', '210', '200', '207', '240', '269', '260', '263'],
#  ['171',
#   '173',
#   '174',
#   '163',
#   '161',
#   '157',
#   '156',
#   '154',
#   '152',
#   '156',
#   '151',
#   '153',
#   '132',
#   '135',
#   '151',
#   '143',
#   '141',
#   '149',
#   '145',
#   '147',
#   '142',
#   '143',
#   '139',
#   '141',
#   '144',
#   '147',
#   '137',
#   '144',
#   '147',
#   '153',
#   '151',
#   '153',
#   '157',
#   '185',
#   '186',
#   '185',
#   '181',
#   '161',
#   '177',
#   '179',
#   '177',
#   '178',
#   '173',
#   '175',
#   '183',
#   '181',
#   '191',
#   '189',
#   '186',
#   '189',
#   '192',
#   '191',
#   '189',
#   '199',
#   '208',
#   '218',
#   '216',
#   '210',
#   '209',
#   '208',
#   '215',
#   '207',
#   '198',
#   '202',
#   '204',
#   '205',
#   '204',
#   '203',
#   '205',
#   '207',
#   '208',
#   '209',
#   '218',
#   '234',
#   '231',
#   '245',
#   '244',
#   '243',
#   '265',
#   '264',
#   '279',
#   '282',
#   '283',
#   '274',
# ...

# %% [markdown]
# ## Day 1
#
# [Here is the link.](https://adventofcode.com/2021/day/1)

# %% [markdown]
# ### Part 1

# %%
data,data1 = get_data() 
data = list(map(int, data))
data
# Out:
# [199, 200, 208, 210, 200, 207, 240, 269, 260, 263]

# %% [markdown]
# #### Test

# %%
pd = None
res = []
for d in data:
    if pd is None:
        res.append(None)
    else:
        if pd>d:
            res.append("0")
        else:
            res.append("1")
    pd=d

# %%
res.count("1")
# Out:
# 7

# %% [markdown]
# #### Real Data

# %%
pd = None
res = []
for d in data1:
    if pd is None:
        res.append(None)
    else:
        if pd>d:
            res.append("0")
        else:
            res.append("1")
    pd=d
res.count("1")
# Out:
# 1265

# %% [markdown]
# ### Part 2

# %%
w = []
wsum = []
i = 0
ps = None
for j in range(3, len(data1)+1):
    wsum.append(sum(data1[i:j]))
    i+=1

pd = None
res1 = []
for d in wsum:
    if pd is None:
        res1.append(None)
    else:
        if pd>=d:
            res1.append("0")
        else:
            res1.append("1")
    pd=d

# %%
res1.count("1")
# Out:
# 1217

# %% [markdown]
# ## Reader function

# %% [markdown]
# # Terminal Section

# %%
! git add .
! git commit -m "solved day1"
! git push origin master
# Out:
# [master 1117aac] solved day1
#  46 files changed, 3287 insertions(+)
#  rename Advent of code.ipynb => 2020/Advent of code.ipynb (100%)
#  rename README.md => 2020/README.md (100%)
#  rename day1.txt => 2020/day1.txt (100%)
#  rename day10.txt => 2020/day10.txt (100%)
#  rename day10_test.txt => 2020/day10_test.txt (100%)
#  rename day11.txt => 2020/day11.txt (100%)
#  rename day11_test.txt => 2020/day11_test.txt (100%)
#  rename day12.txt => 2020/day12.txt (100%)
#  rename day12_test.txt => 2020/day12_test.txt (100%)
#  rename day13.txt => 2020/day13.txt (100%)
#  rename day13_test.txt => 2020/day13_test.txt (100%)
#  rename day14.txt => 2020/day14.txt (100%)
#  rename day14_test.txt => 2020/day14_test.txt (100%)
#  rename day15.txt => 2020/day15.txt (100%)
#  rename day15_test.txt => 2020/day15_test.txt (100%)
#  rename day16.txt => 2020/day16.txt (100%)
#  rename day16_test.txt => 2020/day16_test.txt (100%)
#  rename day17.txt => 2020/day17.txt (100%)
# ...
